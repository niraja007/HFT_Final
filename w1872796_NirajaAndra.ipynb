# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %% [markdown]
# ### Downloading the same day high frequency historical data for ‘BTC’ and ‘ETH’ by using yfinance between 20th Dec 2022 and 21st Dec 2022

# %%
BTC = yf.download('BTC-GBP', start='2022-12-20', end='2022-12-21',  interval = '1m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
BTC
# Out:
#                                    Open          High           Low  \
# Datetime
# 2022-12-20 00:00:00+00:00  13525.039062  13525.039062  13525.039062
# 2022-12-20 00:01:00+00:00  13528.828125  13528.828125  13528.828125
# 2022-12-20 00:03:00+00:00  13540.404297  13540.404297  13540.404297
# 2022-12-20 00:04:00+00:00  13542.943359  13542.943359  13542.943359
# 2022-12-20 00:05:00+00:00  13542.881836  13542.881836  13542.881836
# ...                                 ...           ...           ...
# 2022-12-20 23:54:00+00:00  13864.080078  13864.080078  13864.080078
# 2022-12-20 23:55:00+00:00  13866.120117  13866.120117  13866.120117
# 2022-12-20 23:56:00+00:00  13866.774414  13866.774414  13866.774414
# 2022-12-20 23:57:00+00:00  13867.400391  13867.400391  13867.400391
# 2022-12-20 23:58:00+00:00  13867.500000  13867.500000  13867.500000
#
#                                   Close     Adj Close   Volume
# Datetime
# 2022-12-20 00:00:00+00:00  13525.039062  13525.039062        0
# 2022-12-20 00:01:00+00:00  13528.828125  13528.828125        0
# 2022-12-20 00:03:00+00:00  13540.404297  13540.404297        0
# 2022-12-20 00:04:00+00:00  13542.943359  13542.943359        0
# 2022-12-20 00:05:00+00:00  13542.881836  13542.881836  1983488
# ...                                 ...           ...      ...
# 2022-12-20 23:54:00+00:00  13864.080078  13864.080078        0
# 2022-12-20 23:55:00+00:00  13866.120117  13866.120117        0
# 2022-12-20 23:56:00+00:00  13866.774414  13866.774414        0
# 2022-12-20 23:57:00+00:00  13867.400391  13867.400391   178176
# 2022-12-20 23:58:00+00:00  13867.500000  13867.500000        0
#
# [1418 rows x 6 columns]

# %%
ETH = yf.download('ETH-GBP', start='2022-12-20', end='2022-12-21',  interval = '1m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ETH
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2022-12-20 00:00:00+00:00  960.600830  960.600830  960.600830  960.600830
# 2022-12-20 00:01:00+00:00  960.971313  960.971313  960.971313  960.971313
# 2022-12-20 00:03:00+00:00  961.491943  961.491943  961.491943  961.491943
# 2022-12-20 00:04:00+00:00  961.670593  961.670593  961.670593  961.670593
# 2022-12-20 00:05:00+00:00  961.706177  961.706177  961.706177  961.706177
# ...                               ...         ...         ...         ...
# 2022-12-20 23:54:00+00:00  998.807007  998.807007  998.807007  998.807007
# 2022-12-20 23:55:00+00:00  998.938904  998.938904  998.938904  998.938904
# 2022-12-20 23:56:00+00:00  998.981018  998.981018  998.981018  998.981018
# 2022-12-20 23:57:00+00:00  999.081848  999.081848  999.081848  999.081848
# 2022-12-20 23:58:00+00:00  999.023865  999.023865  999.023865  999.023865
#
#                             Adj Close   Volume
# Datetime
# 2022-12-20 00:00:00+00:00  960.600830        0
# 2022-12-20 00:01:00+00:00  960.971313   309248
# 2022-12-20 00:03:00+00:00  961.491943        0
# 2022-12-20 00:04:00+00:00  961.670593        0
# 2022-12-20 00:05:00+00:00  961.706177   311552
# ...                               ...      ...
# 2022-12-20 23:54:00+00:00  998.807007   361472
# 2022-12-20 23:55:00+00:00  998.938904   651776
# 2022-12-20 23:56:00+00:00  998.981018        0
# 2022-12-20 23:57:00+00:00  999.081848  1262592
# 2022-12-20 23:58:00+00:00  999.023865        0
#
# [1418 rows x 6 columns]

# %%
S1_0 = BTC['Open'][0]
S2_0 = ETH['Open'][0]

# %%
S1_0
# Out:
# 13525.0390625

# %%
S2_0
# Out:
# 960.600830078125

# %%
lr1 = np.log(BTC['Adj Close'] / BTC['Adj Close'].shift(1))
lr2 = np.log(ETH['Adj Close'] / ETH['Adj Close'].shift(1))
mu_1 = lr1.mean() * 1418 # Daily minute return
mu_2 = lr2.mean() * 1418
sigma_1 = lr1.std() * np.sqrt(1418) #daily volatility
sigma_2 = lr2.std() * np.sqrt(1418)
rho = lr1.corr(lr2)
z_0 = 0.00
gamma = 0.5
delta = 1
T = 1
M = len(BTC)

# %%
rho
# Out:
# 0.8987026809398215

# %%
result = linregress(np.log(BTC['Adj Close']), np.log(ETH['Adj Close']))
beta = result.slope

# %%
beta
# Out:
# 1.518788587639171

# %%
dt = T/M
S1 = np.zeros((M + 1, 1))
S2 = np.zeros((M + 1, 1))
z =  np.zeros((M + 1, 1))
a =  np.zeros((M + 1, 1))
b =  np.zeros((M + 1, 1))
c =  np.zeros((M + 1, 1))
Pi_1 = np.zeros((M + 1, 1))
Pi_2 = np.zeros((M + 1, 1))

# %%
tt = np.linspace(0, 1, M + 1)
z[0] = z_0
S1[0] = S1_0
S2[0] = S2_0
sigma_beta = np.sqrt(sigma_1 ** 2 + beta ** 2 * sigma_2 ** 2 + 2 * beta * sigma_1 * sigma_2 * rho)
eta = (-1/delta) * (mu_1 - sigma_1 ** 2/2 + beta*(mu_2 - sigma_2 ** 2/2))
rn = np.random.standard_normal(z.shape)
rn1 = np.random.standard_normal(S1.shape) 
rn2 = np.random.standard_normal(S2.shape) 
for t in range(1, M + 1):
    z[t] = z[t-1]* (1 - delta * (eta - z[t-1])) * dt + sigma_beta * np.sqrt(dt)*((sigma_1 + beta * sigma_2 * rho)/ sigma_beta * rn1[t] + beta * (sigma_2 * np.sqrt(1-rho ** 2)/sigma_beta) * rn1[t]);
    S1[t] = BTC['Adj Close'][t-1]
    S2[t] = ETH['Adj Close'][t-1]

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, S1, 'b', lw=1.5, label='BTC')
plt.plot(tt, S2, 'r', lw=1.5, label='ETH')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Stock Price')
# Out:
# Text(0.5, 1.0, 'Stock Price')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, z, 'g', lw=1.5)
plt.xlabel('Time')
plt.ylabel('Rate')
plt.title('z')
#plot for co-integrated factor
# Out:
# Text(0.5, 1.0, 'z')

# %%
for t in range(1, M + 1):
    a[t] = 0.5 * (T - t * dt)/((1-rho ** 2) * sigma_1 ** 2)
    b[t] = - 0.25 * (T - t * dt) ** 2 * (sigma_1 ** 2 + beta * sigma_2 ** 2)/((1 - rho ** 2) * sigma_1 ** 2) - rho * mu_2 * (T - t * dt)/((1 - rho **2) * sigma_1 * sigma_2)
    c[t] = 0.5 * mu_2 ** 2 * (T - t * dt)/((1 - rho ** 2) * sigma_2 ** 2) + 0.25 * (T - t * dt) ** 2 * (sigma_1 ** 2 + beta * sigma_2 ** 2 + 2 * sigma_1 * sigma_2 * beta *rho) * delta ** 2/((1 - rho ** 2) * sigma_1 ** 2) + 0.25 * (T - t * dt) ** 2 * mu_2 * delta * rho * (sigma_1 ** 2 + beta * sigma_2 ** 2) + 1/24 * (T - t * dt) ** 3 * (sigma_1 ** 2 + beta * sigma_2 ** 2) ** 2 * delta ** 2/((1 - rho ** 2) * sigma_1 ** 2)
    Pi_1[t] = (1 / S1[t]) * ((mu_1 + delta * z[t])/(gamma * (1 - rho ** 2) * sigma_1 ** 2) + delta/gamma * (-2 * a[t] * (mu_1 + delta * z[t])-b[t]) - rho * mu_2/(gamma * (1 - rho ** 2) * sigma_1 * sigma_2))
    Pi_2[t] = (1 / S2[t]) * (mu_2 / (gamma * (1 - rho ** 2) * sigma_2 ** 2) + delta * beta / gamma * (- 2 * a[t] * (mu_1 + delta * z[t]) - b[t]) - rho * (mu_1 + delta * z[t]) / (gamma * (1 - rho ** 2) * sigma_1 * sigma_2))

# %% [markdown]
# Optimal Weights

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1, 'b', lw=1.5, label='w1')
plt.plot(tt, Pi_2, 'r', lw=1.5, label='w2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('%')
plt.title('Weights')
# Out:
# Text(0.5, 1.0, 'Weights')

# %% [markdown]
# Optimal cash Process - Negative means selling and you get cash

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1 * S1, 'b', lw=1.5, label='Wealth 1')
plt.plot(tt, Pi_2 * S2, 'r', lw=1.5, label='Wealth 2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Cash')
# Out:
# Text(0.5, 1.0, 'Cash')

# %%
Pi_1.mean()
# Out:
# -0.012703028949544013

# %%
Pi_2.mean()
# Out:
# 0.8808353830192246

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1 * S1 + Pi_2 * S2, 'b', lw=1.5, label='Dynamic')
plt.plot(tt, Pi_1.mean() * S1 + Pi_2.mean() * S2, 'r', lw=1.5, label='Static')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Comparison')
# Out:
# Text(0.5, 1.0, 'Comparison')

# %%
Wealth = abs(Pi_1 * S1) + abs(Pi_2 * S2)

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt[1:-1], Wealth[1:-1], 'b', lw=1.5, label='Total')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('total')
# Out:
# Text(0.5, 1.0, 'total')

# %%
#daily return 
(Wealth[-1]-Wealth[1])/Wealth[1]
# Out:
# array([0.26800581])

# %% [markdown]
# Inital Wealth

# %%
Wealth[1]
# Out:
# array([1157.07884553])

# %% [markdown]
# Ending Wealth

# %%
Wealth[-1]
# Out:
# array([1029.72808014])

# %% [markdown]
# Return

# %%
(Wealth[-1] - Wealth[1])/Wealth[1]
# Out:
# array([-0.11006231])

# %% [markdown]
# ## Assets - Simulation and real data

# %%
S1_0 = BTC['Open'][0]
S2_0 = 7085

# %%
lr1 = np.log(BTC['Adj Close'] / BTC['Adj Close'].shift(1))

mu_1 = lr1.mean() * 1418
mu_2 = 0.02
sigma_1 = lr1.std() * np.sqrt(1418)
sigma_2 = 0.1
rho = -0.7
z_0 = 0.0001
gamma = 0.5
delta = 1
T = 1
M = len(BTC)
beta = 1

# %%
dt = T/M
S1 = np.zeros((M + 1, 1))
S2 = np.zeros((M + 1, 1))
z =  np.zeros((M + 1, 1))
a =  np.zeros((M + 1, 1))
b =  np.zeros((M + 1, 1))
c =  np.zeros((M + 1, 1))
Pi_1 = np.zeros((M + 1, 1))
Pi_2 = np.zeros((M + 1, 1))

# %%
tt = np.linspace(0, 1, M + 1)
z[0] = z_0
S1[0] = S1_0
S2[0] = S2_0
sigma_beta = np.sqrt(sigma_1 ** 2 + beta ** 2 * sigma_2 ** 2 + 2 * beta * sigma_1 * sigma_2 * rho)
eta = (-1/delta) * (mu_1 - sigma_1 ** 2/2 + beta*(mu_2 - sigma_2 ** 2/2))
rn = np.random.standard_normal(z.shape)
rn1 = np.random.standard_normal(S1.shape) 
rn2 = np.random.standard_normal(S2.shape) 
for t in range(1, M + 1):
    z[t] = z[t-1]* (1 - delta * (eta - z[t-1])) * dt + sigma_beta * np.sqrt(dt)*((sigma_1 + beta * sigma_2 * rho)/ sigma_beta * rn1[t] + beta * (sigma_2 * np.sqrt(1-rho ** 2)/sigma_beta) * rn1[t]);
    S1[t] = BTC['Adj Close'][t-1]
    S2[t] = S2[t-1] * np.exp((mu_2 - sigma_2 ** 2 / 2) * dt + sigma_2 * np.sqrt(dt) * (rho * rn1[t] + np.sqrt(1 - rho ** 2) * rn2[t]))

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, S1, 'b', lw=1.5, label='BTC')
plt.plot(tt, S2, 'r', lw=1.5, label='ETH')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Stock Price')
# Out:
# Text(0.5, 1.0, 'Stock Price')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, z, 'g', lw=1.5)
plt.xlabel('Time')
plt.ylabel('Rate')
plt.title('z')
#plot for co-integrated factor
# Out:
# Text(0.5, 1.0, 'z')

# %% [markdown]
# ### Optimal Weight

# %%
for t in range(1, M + 1):
    a[t] = 0.5 * (T - t * dt)/((1-rho ** 2) * sigma_1 ** 2)
    b[t] = - 0.25 * (T - t * dt) ** 2 * (sigma_1 ** 2 + beta * sigma_2 ** 2)/((1 - rho ** 2) * sigma_1 ** 2) - rho * mu_2 * (T - t * dt)/((1 - rho **2) * sigma_1 * sigma_2)
    c[t] = 0.5 * mu_2 ** 2 * (T - t * dt)/((1 - rho ** 2) * sigma_2 ** 2) + 0.25 * (T - t * dt) ** 2 * (sigma_1 ** 2 + beta * sigma_2 ** 2 + 2 * sigma_1 * sigma_2 * beta *rho) * delta ** 2/((1 - rho ** 2) * sigma_1 ** 2) + 0.25 * (T - t * dt) ** 2 * mu_2 * delta * rho * (sigma_1 ** 2 + beta * sigma_2 ** 2) + 1/24 * (T - t * dt) ** 3 * (sigma_1 ** 2 + beta * sigma_2 ** 2) ** 2 * delta ** 2/((1 - rho ** 2) * sigma_1 ** 2)
    Pi_1[t] = (1 / S1[t]) * ((mu_1 + delta * z[t])/(gamma * (1 - rho ** 2) * sigma_1 ** 2) + delta/gamma * (-2 * a[t] * (mu_1 + delta * z[t])-b[t]) - rho * mu_2/(gamma * (1 - rho ** 2) * sigma_1 * sigma_2))
    Pi_2[t] = (1 / S2[t]) * (mu_2 / (gamma * (1 - rho ** 2) * sigma_2 ** 2) + delta * beta / gamma * (- 2 * a[t] * (mu_1 + delta * z[t]) - b[t]) - rho * (mu_1 + delta * z[t]) / (gamma * (1 - rho ** 2) * sigma_1 * sigma_2))

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1, 'b', lw=1.5, label='w1')
plt.plot(tt, Pi_2, 'r', lw=1.5, label='w2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('%')
plt.title('Weights')
# Out:
# Text(0.5, 1.0, 'Weights')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1 * S1, 'b', lw=1.5, label='Wealth 1')
plt.plot(tt, Pi_2 * S2, 'r', lw=1.5, label='Wealth 2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Cash')

#Optimal cash Process - Negative means selling and you get cash
# Out:
# Text(0.5, 1.0, 'Cash')

# %%
Wealth = abs(Pi_1 * S1) + abs(Pi_2 * S2)

# %%
Pi_1.mean()
# Out:
# 0.018947869270443816

# %%
Pi_2.mean()
# Out:
# -0.025092689471907514

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1 * S1 + Pi_2 * S2, 'b', lw=1.5, label='Dynamic')
plt.plot(tt, Pi_1.mean() * S1 + Pi_2.mean() * S2, 'r', lw=1.5, label='Static')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Comparison')
# Out:
# Text(0.5, 1.0, 'Comparison')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt[1:-1], Wealth[1:-1], 'b', lw=1.5, label='Total')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Wealth')
# Out:
# Text(0.5, 1.0, 'Wealth')

# %%
Wealth[1]
#inital wealth
# Out:
# array([432.06347978])

# %%
Wealth[-1]
#final wealth
# Out:
# array([547.85900291])

# %%
(Wealth[-1] - Wealth[1])/Wealth[1]
#return
# Out:
# array([0.26800581])
